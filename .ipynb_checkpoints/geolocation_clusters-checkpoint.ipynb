# %% [markdown]
# Credits, Actual Implemetation: Hamza Bendemra <br>
# Logic implemented with another geolocation data for learning purpose

# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
from bs4 import BeautifulSoup as Soup

# %%
map_kml = "location.kml" # imported kml file from Google Maps

# %%
with open('location.kml') as data:
    kml_soup = Soup(data, 'lxml-xml') # Parse as XML
coords = kml_soup.find_all('coordinates') # find all the coordinates
coords_list = []
for x in coords:
    coords_list.append(str(x)) # store the coordinates in a list

# %%
names = kml_soup.find_all('name') # find all the landmark names in the XML
names_list = []
for x in names:
    names_list.append(str(x)) # store the landmark names in a list

# %%
names_list
# Out:
# ['<name>Nada/Yasmine France Trip</name>',
#  '<name>Day 1 [Sunday]</name>',
#  '<name>HÃ´tel Princesse Caroline</name>',
#  '<name>French Alliance Paris Ile-De-France</name>',
#  '<name>TrocadÃ©ro Gardens</name>',
#  '<name>Eiffel Tower</name>',
#  '<name>Place du Tertre (Cafe, Food)</name>',
#  '<name>The Basilica of the Sacred Heart of Paris</name>',
#  '<name>Louis Vuitton Maison Champs Ã‰lysÃ©es</name>',
#  '<name>Galeries Lafayette</name>',
#  '<name>Printemps Haussmann</name>',
#  '<name>Palais Garnier</name>',
#  '<name>Louvre Museum</name>',
#  '<name>Palace of Versailles (Optional)</name>',
#  '<name>Boat Trip (Bateaux-Mouches)</name>',
#  '<name>Disneyland Paris</name>',
#  '<name>Hotel Louison</name>',
#  '<name>Disneyland Paris</name>',
#  '<name>The Centre Pompidou</name>',
#  '<name>CathÃ©drale Notre-Dame de Paris</name>',
#  '<name>Luxembourg Gardens [Tu]</name>',
#  '<name>Pont Neuf [Tu]</name>',
#  '<name>La VallÃ©e Village [Wed]</name>',
#  '<name>Champs-Ã‰lysÃ©es</name>',
#  "<name>Gare MusÃ©e d'Orsay</name>",
#  '<name>Sainte-Chapelle de Vincennes</name>',
#  '<name>Orangerie Museum</name>',
#  '<name>Le Marais</name>',
#  '<name>MusÃ©e Rodin</name>',
#  '<name>Saint-Germain-des-PrÃ©s</name>',
#  '<name>MusÃ©e Jacquemart-AndrÃ©</name>']

# %%
# create new dataframe
coord_col = ['Longitude', 'Latitude', 'Landmark']
df_coord = pd.DataFrame(columns=coord_col) 
# split coordinates list into coordinates to populate the dataframe
for i, j in zip(range(len(coords_list)), range(2, len(names_list))):
    item = coords_list[i]
    string_split = item.split(',')
    coord1 = float(string_split[0][26:])
    coord2 = float(string_split[1])
    coord3 = names_list[j][6:-7]
    df_coord.loc[i] = [coord1, coord2, coord3]

# %%
df_coord
# Out:
#     Longitude   Latitude                                   Landmark
# 0    2.295617  48.875628                  HÃ´tel Princesse Caroline
# 1    2.328729  48.846361        French Alliance Paris Ile-De-France
# 2    2.289282  48.861596                         TrocadÃ©ro Gardens
# 3    2.294483  48.858370                               Eiffel Tower
# 4    2.340802  48.886503               Place du Tertre (Cafe, Food)
# 5    2.343023  48.886706  The Basilica of the Sacred Heart of Paris
# 6    2.300375  48.871669      Louis Vuitton Maison Champs Ã‰lysÃ©es
# 7    2.330479  48.873820                         Galeries Lafayette
# 8    2.327793  48.873977                        Printemps Haussmann
# 9    2.331767  48.871934                             Palais Garnier
# 10   2.337644  48.860611                              Louvre Museum
# 11   2.120355  48.804865            Palace of Versailles (Optional)
# 12   2.305937  48.864011                Boat Trip (Bateaux-Mouches)
# 13   2.775808  48.872234                           Disneyland Paris
# 14   2.321345  48.845294                              Hotel Louison
# 15   2.775808  48.872234                           Disneyland Paris
# 16   2.352245  48.860642                        The Centre Pompidou
# 17   2.349902  48.852968            CathÃ©drale Notre-Dame de Paris
# 18   2.337160  48.846222                    Luxembourg Gardens [Tu]
# 19   2.341325  48.857050                             Pont Neuf [Tu]
# 20   2.784017  48.853465                   La VallÃ©e Village [Wed]
# 21   2.307314  48.865784                           Champs-Ã‰lysÃ©es
# 22   2.325417  48.860501                        Gare MusÃ©e d'Orsay
# 23   2.436470  48.842348               Sainte-Chapelle de Vincennes
# 24   2.322672  48.863788                           Orangerie Museum
# 25   2.358804  48.858703                                  Le Marais
# 26   2.315785  48.855334                               MusÃ©e Rodin
# 27   2.333328  48.853798                    Saint-Germain-des-PrÃ©s
# 28   2.310532  48.875448                   MusÃ©e Jacquemart-AndrÃ©

# %%
fig = plt.figure(figsize=(16,8))
cmap=plt.cm.rainbow
norm = matplotlib.colors.BoundaryNorm(np.arange(0,10,1), cmap.N)
plt.scatter(df_coord['Longitude'], df_coord['Latitude'],
            cmap=cmap, norm=norm, s=150, edgecolor='none')
plt.xlabel('Latitude', fontsize=18)
plt.ylabel('Longitude', fontsize=18)
plt.grid()
plt.show()

# %% [markdown]
# ### K-means clustering for Geo Location

# %%
from sklearn.cluster import KMeans # Importing KMeans
# Creating an instance of KMeans to find 10 clusters
kmeans_1 = KMeans(n_clusters=10)
# Using fit_predict to cluster the dataset
X = df_coord[['Longitude','Latitude']].values
predictions = kmeans_1.fit_predict(X)

# %%
clustered = pd.concat([df_coord.reset_index(), 
                       pd.DataFrame({'Cluster':predictions})], 
                      axis=1)

# %%
clustered.drop('index', axis=1, inplace=True)

# %%
conditions = [
    clustered['Cluster'] == 0, 
    clustered['Cluster'] == 1,
    clustered['Cluster'] == 2,
    clustered['Cluster'] == 3,
    clustered['Cluster'] == 4,
    clustered['Cluster'] == 5,
    clustered['Cluster'] == 6,
    clustered['Cluster'] == 7,
    clustered['Cluster'] == 8,
    clustered['Cluster'] == 9 ]
choices = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday','Saturday', 
           'Sunday', 'Monday', 'Tuesday', 'Wednesday' ]
clustered['Vacation Day'] = np.select(conditions, choices, default='black')

# %%
clustered.sort_values(by=['Cluster'])
# Out:
#     Longitude   Latitude                                   Landmark  Cluster  \
# 22   2.325417  48.860501                        Gare MusÃ©e d'Orsay        0
# 26   2.315785  48.855334                               MusÃ©e Rodin        0
# 24   2.322672  48.863788                           Orangerie Museum        0
# 15   2.775808  48.872234                           Disneyland Paris        1
# 20   2.784017  48.853465                   La VallÃ©e Village [Wed]        1
# 13   2.775808  48.872234                           Disneyland Paris        1
# 0    2.295617  48.875628                  HÃ´tel Princesse Caroline        2
# 3    2.294483  48.858370                               Eiffel Tower        2
# 2    2.289282  48.861596                         TrocadÃ©ro Gardens        2
# 11   2.120355  48.804865            Palace of Versailles (Optional)        3
# 23   2.436470  48.842348               Sainte-Chapelle de Vincennes        4
# 17   2.349902  48.852968            CathÃ©drale Notre-Dame de Paris        5
# 10   2.337644  48.860611                              Louvre Museum        5
# 16   2.352245  48.860642                        The Centre Pompidou        5
# 25   2.358804  48.858703                                  Le Marais        5
# 19   2.341325  48.857050                             Pont Neuf [Tu]        5
# 5    2.343023  48.886706  The Basilica of the Sacred Heart of Paris        6
# 4    2.340802  48.886503               Place du Tertre (Cafe, Food)        6
# 21   2.307314  48.865784                           Champs-Ã‰lysÃ©es        7
# 28   2.310532  48.875448                   MusÃ©e Jacquemart-AndrÃ©        7
# 12   2.305937  48.864011                Boat Trip (Bateaux-Mouches)        7
# 6    2.300375  48.871669      Louis Vuitton Maison Champs Ã‰lysÃ©es        7
# 27   2.333328  48.853798                    Saint-Germain-des-PrÃ©s        8
# 1    2.328729  48.846361        French Alliance Paris Ile-De-France        8
# 18   2.337160  48.846222                    Luxembourg Gardens [Tu]        8
# 14   2.321345  48.845294                              Hotel Louison        8
# 9    2.331767  48.871934                             Palais Garnier        9
# 8    2.327793  48.873977                        Printemps Haussmann        9
# 7    2.330479  48.873820                         Galeries Lafayette        9
#
#    Vacation Day
# 22       Monday
# 26       Monday
# 24       Monday
# 15      Tuesday
# 20      Tuesday
# 13      Tuesday
# 0     Wednesday
# 3     Wednesday
# 2     Wednesday
# 11     Thursday
# 23       Friday
# 17     Saturday
# 10     Saturday
# 16     Saturday
# 25     Saturday
# 19     Saturday
# 5        Sunday
# 4        Sunday
# 21       Monday
# 28       Monday
# 12       Monday
# 6        Monday
# 27      Tuesday
# 1       Tuesday
# 18      Tuesday
# 14      Tuesday
# 9     Wednesday
# 8     Wednesday
# 7     Wednesday

# %%
fig = plt.figure(figsize=(16,8))
cmap=plt.cm.rainbow
norm = matplotlib.colors.BoundaryNorm(np.arange(0,10,1), cmap.N)
plt.scatter(clustered['Longitude'], clustered['Latitude'], c=clustered['Cluster'],
            cmap=cmap, norm=norm, s=150, edgecolor='none')
plt.colorbar(ticks=np.linspace(0,9,10))
centers = kmeans_1.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=100, alpha=0.3);
#plt.xlim(2.28, 2.375)
#plt.ylim(48.84, 48.89)
plt.xlabel('Latitude', fontsize=14)
plt.ylabel('Longitude', fontsize=14)
plt.title('k-means clustering results (n_clusters=10)', fontsize=14)
plt.grid()
plt.show()

# %%
fig = plt.figure(figsize=(16,8))
cmap=plt.cm.rainbow
norm = matplotlib.colors.BoundaryNorm(np.arange(0,10,1), cmap.N)
plt.scatter(clustered['Longitude'], clustered['Latitude'], c=clustered['Cluster'],
            cmap=cmap, norm=norm, s=150, edgecolor='none')
plt.colorbar(ticks=np.linspace(0,9,10))
centers = kmeans_1.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=100, alpha=0.3);
plt.xlim(2.28, 2.375)
plt.ylim(48.84, 48.89)
plt.xlabel('Latitude', fontsize=14)
plt.ylabel('Longitude', fontsize=14)
plt.title('k-means clustering results (n_clusters=10)', fontsize=14)
plt.grid()
plt.show()

# %% [markdown]
# ### HDBSCAN for Geo Location

# %%
import hdbscan

# %%
rads = np.radians(X)
clusterer = hdbscan.HDBSCAN(min_cluster_size=2, metric='haversine')
predictions = clusterer.fit_predict(rads)

# %%
clustered = pd.concat([df_coord.reset_index(), 
                       pd.DataFrame({'Cluster':predictions})], 
                      axis=1)
clustered.drop('index', axis=1, inplace=True)
conditions = [
    clustered['Cluster'] == -1, 
    clustered['Cluster'] == 0,
    clustered['Cluster'] == 1,
    clustered['Cluster'] == 2,
    clustered['Cluster'] == 3,
    clustered['Cluster'] == 4,
    clustered['Cluster'] == 5,
    clustered['Cluster'] == 6,
    clustered['Cluster'] == 7,
    clustered['Cluster'] == 8 ]
choices = ['NA/Noise', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 
           'Friday','Saturday', 'Sunday', 'Monday', 'Tuesday' ]
clustered['Vacation Day'] = np.select(conditions, choices, default='black')
clustered.sort_values(by=['Cluster'])
# Out:
#     Longitude   Latitude                                   Landmark  Cluster  \
# 28   2.310532  48.875448                   MusÃ©e Jacquemart-AndrÃ©       -1
# 26   2.315785  48.855334                               MusÃ©e Rodin       -1
# 23   2.436470  48.842348               Sainte-Chapelle de Vincennes       -1
# 11   2.120355  48.804865            Palace of Versailles (Optional)       -1
# 20   2.784017  48.853465                   La VallÃ©e Village [Wed]        0
# 15   2.775808  48.872234                           Disneyland Paris        0
# 13   2.775808  48.872234                           Disneyland Paris        0
# 4    2.340802  48.886503               Place du Tertre (Cafe, Food)        1
# 5    2.343023  48.886706  The Basilica of the Sacred Heart of Paris        1
# 2    2.289282  48.861596                         TrocadÃ©ro Gardens        2
# 3    2.294483  48.858370                               Eiffel Tower        2
# 7    2.330479  48.873820                         Galeries Lafayette        3
# 8    2.327793  48.873977                        Printemps Haussmann        3
# 9    2.331767  48.871934                             Palais Garnier        3
# 0    2.295617  48.875628                  HÃ´tel Princesse Caroline        4
# 6    2.300375  48.871669      Louis Vuitton Maison Champs Ã‰lysÃ©es        4
# 12   2.305937  48.864011                Boat Trip (Bateaux-Mouches)        5
# 21   2.307314  48.865784                           Champs-Ã‰lysÃ©es        5
# 22   2.325417  48.860501                        Gare MusÃ©e d'Orsay        6
# 24   2.322672  48.863788                           Orangerie Museum        6
# 16   2.352245  48.860642                        The Centre Pompidou        7
# 17   2.349902  48.852968            CathÃ©drale Notre-Dame de Paris        7
# 25   2.358804  48.858703                                  Le Marais        7
# 18   2.337160  48.846222                    Luxembourg Gardens [Tu]        8
# 1    2.328729  48.846361        French Alliance Paris Ile-De-France        8
# 14   2.321345  48.845294                              Hotel Louison        8
# 19   2.341325  48.857050                             Pont Neuf [Tu]        9
# 10   2.337644  48.860611                              Louvre Museum        9
# 27   2.333328  48.853798                    Saint-Germain-des-PrÃ©s        9
#
#    Vacation Day
# 28     NA/Noise
# 26     NA/Noise
# 23     NA/Noise
# 11     NA/Noise
# 20       Monday
# 15       Monday
# 13       Monday
# 4       Tuesday
# 5       Tuesday
# 2     Wednesday
# 3     Wednesday
# 7      Thursday
# 8      Thursday
# 9      Thursday
# 0        Friday
# 6        Friday
# 12     Saturday
# 21     Saturday
# 22       Sunday
# 24       Sunday
# 16       Monday
# 17       Monday
# 25       Monday
# 18      Tuesday
# 1       Tuesday
# 14      Tuesday
# 19        black
# 10        black
# 27        black

# %%
fig = plt.figure(figsize=(16,8))
cmap=plt.cm.gnuplot2
#norm = matplotlib.colors.BoundaryNorm(np.arange(0,10,1), cmap.N)
plt.scatter(clustered['Longitude'], clustered['Latitude'], c=clustered['Cluster'],
            cmap=cmap, s=100, edgecolor='none')
plt.colorbar(ticks=[-1,0,1,2,3,4,5,6,7,8])
centers = kmeans_1.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=100, alpha=0.3);
#plt.xlim(2.28, 2.375)
#plt.ylim(48.84, 48.89)
plt.xlabel('Latitude', fontsize=14)
plt.ylabel('Longitude', fontsize=14)
plt.title('HDBSCAN clustering results', fontsize=14)
plt.grid()
plt.show()

# %%
fig = plt.figure(figsize=(16,8))
cmap=plt.cm.gnuplot2
#norm = matplotlib.colors.BoundaryNorm(np.arange(0,10,1), cmap.N)
plt.scatter(clustered['Longitude'], clustered['Latitude'], c=clustered['Cluster'],
            cmap=cmap, s=100, edgecolor='none')
plt.colorbar(ticks=[-1,0,1,2,3,4,5,6,7,8])
centers = kmeans_1.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=100, alpha=0.3);
plt.xlim(2.28, 2.375)
plt.ylim(48.84, 48.89)
plt.xlabel('Latitude', fontsize=14)
plt.ylabel('Longitude', fontsize=14)
plt.title('HDBSCAN clustering results', fontsize=14)
plt.grid()
plt.show()

# %%
## ChIJ-bfVTh8VkFQRDZLQnmioK9s
